# %%
import util

# %%
util.run()
# Out:
# 분석 시작 지점을 예시와 같이 입력하시오 (ex. 2024년 1월 1일 -> 20240101) 20240101
# 분석 종료 지점을 예시와 같이 입력하시오 (ex. 2024년 1월 1일 -> 20240101) 20240101
# 	분석 시작일 : 2024년 01월 01일
# 	분석 종료일 : 2024년 01월 01일
# 맞으면 y, 틀리면 n을 입력하시오([y]/n)
# cleaning data...	DONE (start: 2024-05-08 23:33:37.492627, end: 2024-05-08 23:33:37.818539, time: 0:00:00.325912
# tokenizing data...	DONE (start: 2024-05-08 23:33:37.818539, end: 2024-05-08 23:33:58.532741, time: 0:00:20.714202
# reshaping data...melt : 12050 records
#
# now on record	0	1000	2000	3000	4000	5000	6000	7000	8000	9000
# now on record	10000	11000	12000
# 	DONE (start: 2024-05-08 23:33:58.533744, end: 2024-05-08 23:34:33.957630, time: 0:00:35.423886

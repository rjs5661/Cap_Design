# %% [markdown]
# data_loader에서 구현할 것
#
# - 예상 시간 산출 기능 -> data_loader
# - 데이터 적재 전체 과정 정의 후 구현 -> data_loader
# - 세이브 포인트 기능 -> 일정 시간 단위로 가져올 때 마지막으로 가져왔던 위치를 안다면 가져오는 시간 절약 가능

# %% [markdown]
# 데이터 적재(+그 후 넘겨주기까지) 과정
#
# - 사용자가 분석 기간 입력 -> 구현 완료
# - 해당 기간의 데이터를 '로컬 저장소'에서 불러오기 : DB가 되었건, 피클이건, ...
#     - 만약 없다면? -> 이런 일 없도록 일정 시간 단위로 긁어오게 시킬 것
# - 메모리에 데이터 적재
# - prep할 수 있게 넘겨주기

# %%
from bs4 import BeautifulSoup
from datetime import datetime
import numpy as np
import os
import pandas as pd
import pickle
import re
import requests
from sys import stdout
import time

WRKON_JUPYTER = os.path.exists(os.path.abspath('../../resources'))

# %%
def get_user_input():
    start = input('분석 시작 지점을 예시와 같이 입력하시오 (ex. 2024년 1월 1일 -> 20240101)')
    end = input('분석 종료 지점을 예시와 같이 입력하시오 (ex. 2024년 1월 1일 -> 20240101)')

    print(
        f"\n\t분석 시작일 : {start[:4]}년 {start[4:6]}월 {start[6:]}일\n\t분석 종료일 : {end[:4]}년 {end[4:6]}월 {end[6:]}일\n"
    )
    is_proceed = input('맞으면 y, 틀리면 n을 입력하시오([y]/n)')
    
    if (is_proceed == 'y') or (is_proceed == '') :
        return start, end
    else:
        print("분석을 종료합니다\n\n")
        return None, None

# %%
def load_raw_data(start, end):
    
    fpath = '../../data/' if WRKON_JUPYTER else '../data/'
    
    raw_data_list = []
    
    period = pd.date_range(start, end).strftime('%Y%m%d')

    for date in period:
        raw_data = pd.read_csv(
            fpath+date+'.csv',
            col
        )
        raw_data['dates'] = date
        raw_data_list.append(raw_data)

    df = pd.concat(raw_data_list).reset_index(drop=True)

    return df

# %%
def get_title_cnt(date, sid1='001'):

    BASE_URL = f'https://news.naver.com/main/list.naver?mode=LSD&mid=sec&sid1={sid1}&listType=title&'

    last_page = 1000
    n_titles = 0

    while True:
        url = BASE_URL
        url += f'date={date}&'
        url += f'page={last_page}'

        res = requests.get(url)
        bs = BeautifulSoup(res.text, features='html.parser')
        time.sleep(0.1)

        has_next = bs.find('a', class_='next nclicks(fls.page)')
        page_list = bs.find('div', class_='paging')
        
        if not has_next and last_page >= int(page_list.find('strong').get_text()):
            last_page = int(page_list.find('strong').get_text())
            n_titles = len(bs.find_all('a', class_="nclicks(fls.list)"))
            break
        else :
            last_page += 1000
    
    return (last_page - 1) * 50 + n_titles

# %%
def get_title_cnt_in_period(date_start, date_end, sid1='001'):
    
    title_cnt = pd.date_range(date_start, date_end).strftime("%Y%m%d").to_series()
    title_cnt = title_cnt.apply(get_title_cnt, sid1=sid1)
    title_cnt = title_cnt.sum()

    return title_cnt

# %%
def crawl(start, end, time_sleep=0.5, page_start=1) :
    BASE_URL = 'https://news.naver.com/main/list.naver?mode=LSD&mid=sec&listType=title&'

    period = pd.date_range(start, end).strftime('%Y%m%d')
    prompt = ''
    
    for date in period:
        
        raw_data = []
        max_page = get_title_cnt(date) // 50 + 1
        page = page_start
        pct = 0
        crawl_start = datetime.now()
        
        while True:            
            url = BASE_URL
            url += f'date={date}&'
            url += f'page={page}'
    
            res = requests.get(url)
            bs = BeautifulSoup(res.text, features='html.parser')
            time.sleep(time_sleep)

            raw_titles = [e.get_text() for e in bs.find_all('a', class_="nclicks(fls.list)")]
            raw_data.extend(raw_titles)

            pct = int(page * 100 / max_page)
            prompt = f'\r{date} ( MAX PAGE : {max_page} ) : '
            prompt += f'{page}, {pct}%'
            stdout.write(prompt)

            has_next = bs.find('a', class_='next nclicks(fls.page)')
            page_list = bs.find('div', class_='paging')
            
            if not has_next and int(page_list.find('strong').get_text()) >= max_page:
                break
            else : 
                page += 1

        prompt = '\tDONE '
        prompt += f'(start: {crawl_start}, '
        prompt += f'end: {datetime.now()}, '
        prompt += f'time: {datetime.now() - crawl_start}) / '
        
        stdout.write(prompt)

        if WRKON_JUPYTER : 
            save_raw_data(pd.Series(raw_data, name='titles'), fname=date+'.csv', fpath='../../data/')
        else : 
            save_raw_data(pd.Series(raw_data, name='titles'), fname=date+'.csv', fpath='../data/')

    return True

# %%
def save_raw_data(raw_data, fname, fpath):
    
    print('saving... ', end='')
    raw_data.to_csv(fpath+fname, index=False)
    print('DONE')

    return True

# %%
def convert_pkl_to_csv(fname):
    fpath = ''
    if WRKON_JUPYTER : 
        fpath='../../data/'
    else : 
        fpath='../data/'

    data = pd.read_pickle(fpath + fname)
    data = pd.Series(data['titles'], name='titles')
    data.to_csv(fpath+fname[:-4]+'.csv', index=False)
    return True

# %%
for date in ['20240101', '20240102', '20240103']:
    convert_pkl_to_csv(date + '.pkl')
# Out:
# 0             [사설]尹 3년차도 “카르텔 타파”… 이젠 개혁과제 실행에 더 진력해야
# 1               일본서 한신 대지진보다 큰 규모 7.6 강진…"피해 현황 집계 중"
# 2                         동해안에도 지진해일 여파...인명·물적 피해 없어
# 3                            [라인W 날씨] 내일 오전까지 중부에 눈·비
# 4             성낙인 창녕군수 “2024년 청룡처럼 비상하는 창녕 되도록 노력할 것”
# 5            [사설]韓 2년 연속 무역적자, 새해 ‘반도체의 봄’만 기대하고 있기엔…
# 6    ‘관동대지진’ 100년만에...진도 1부터 7까지 일본 전역이 영향권[이시카와현 지진]
# 7      [신년사] 조규일 진주시장 "미래 성장동력 확보해 제3의 진주 기적 이뤄 나가겠다"
# 8                         평창 가스충전소 화재로 5명 중경상...주민 대피
# 9                      평창 가스 충전소 폭발...5명 다치고 인근 지역 정전
# Name: titles, dtype: object
# 0        이수정 "이재명 습격범, 정신질환 아냐…나름의 목적 있을 것"
# 1      테슬라 작년 4분기 48만대 인도…中비야디 53만대에 뒤져(종합)
# 2             정부 “평창 LPG 충전소 폭발 재발방지 대책 추진”
# 3       [날씨] 내일 전국 곳곳에 눈·비…“빙판길 안전 운전 하세요!”
# 4       [사설]초유의 무허가 방송 사태 초래한 기형적 방통위 2인 체제
# 5            홍남표 창원시장,  새해 미래 50년 먹거리 사업 챙겨
# 6                 속초시, 올해 교육경비 보조금 18억 원 지원
# 7                  “내년 도입 예정 금융투자소득세 폐지 추진”
# 8               동해시, 지난해 고향사랑 기부금 목표액 초과 달성
# 9    [사설]초중고 1명당 교부금 8년 뒤 3천만원… 교육 재정 독점 풀라
# Name: titles, dtype: object
# 0         검찰, '이재명 습격' 피의자 구속영장 청구…4일 오후 2시 영장실질심사
# 1    JAPAN-ISHIKAWA-EARTHQUAKES-TEMPORARY SHELTERS
# 2       [사설]中 BYD 테슬라 제치고 판매 1위… 韓 ‘전기차 대전’ 준비돼 있나
# 3                       그 시절 음악과 너와 함께라면 두려울 것 없었네
# 4    JAPAN-ISHIKAWA-EARTHQUAKES-TEMPORARY SHELTERS
# 5    JAPAN-ISHIKAWA-EARTHQUAKES-TEMPORARY SHELTERS
# 6    JAPAN-ISHIKAWA-EARTHQUAKES-TEMPORARY SHELTERS
# 7    JAPAN-ISHIKAWA-EARTHQUAKES-TEMPORARY SHELTERS
# 8             MIDEAST ISRAEL PALESTINIANS CONFLICT
# 9                이재명 대표 급습 피의자 구속영장 청구…4일 실질심사(종합)
# Name: titles, dtype: object

# %%
import pickle

# %%
with open('../../data/20240101.pkl', 'rb') as f:
    p = pickle.load(f)

# %%
p
# Out:
# {'titles': ['[사설]尹 3년차도 “카르텔 타파”… 이젠 개혁과제 실행에 더 진력해야',
#   '일본서 한신 대지진보다 큰 규모 7.6 강진…"피해 현황 집계 중"',
#   '동해안에도 지진해일 여파...인명·물적 피해 없어',
#   '[라인W 날씨] 내일 오전까지 중부에 눈·비',
#   '성낙인 창녕군수 “2024년 청룡처럼 비상하는 창녕 되도록 노력할 것”',
#   '[사설]韓 2년 연속 무역적자, 새해 ‘반도체의 봄’만 기대하고 있기엔…',
#   '‘관동대지진’ 100년만에...진도 1부터 7까지 일본 전역이 영향권[이시카와현 지진]',
#   '[신년사] 조규일 진주시장 "미래 성장동력 확보해 제3의 진주 기적 이뤄 나가겠다"',
#   '평창 가스충전소 화재로 5명 중경상...주민 대피',
#   '평창 가스 충전소 폭발...5명 다치고 인근 지역 정전',
#   '밀양 분기점 부근 4중 추돌사고...1명 숨지고 3명 다쳐',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   '4중 추돌 사고 나자 20여 명 달려와 사고 수습 도와',
#   '새만금 방조제 인근 텐트에서 50대 남녀 숨진 채 발견',
#   '[횡설수설/우경임]1441일 만에 문 닫은 코로나 선별진료소',
#   '[영상] 평창 LPG 충전소 가스 누출로 연쇄 폭발…블랙박스 영상',
#   'GERMANY SKI JUMPING',
#   'PAKISTAN HUMAN RIGHTS',
#   'PAKISTAN HUMAN RIGHTS',
#   '[오늘과 내일/장택동]말만 앞세운 空論으론 해결 못 할 재판 지연',
#   '[간추린 뉴스] 월소득 213만 원 이하면 기초연금 수령 외',
#   '[동아시론/박원곤]다중고에 직면한 김정은의 새해',
#   '국민 절반 “소득 5만달러 중추국가 도약 눈앞”',
#   '일본 기상청 "밤 11시 3분 이시카와현에 규모 4.6 지진 추가로 관측"',
#   "[신년사] 이동환 고양시장 “경제자유구역·첨단기업 등 유치해 고양의 '성공시대' 열겠다”",
#   '[광화문에서/신진우]국정원은 불만, 경찰은 부담… 누굴 위해 수사권을 넘겼나',
#   '尹, 신년사 통해 “민생 회복의 한 해” 굳은 약속…부동산 등 부각',
#   '일본 지진에 동해해경, 지진해일 피해 예방 총력 대응',
#   '평창 LPG충전소 폭발 화재 진화, 불 번진 인근 건물 진화 중(종합)',
#   '“군 간부 1인 1실”…달라지는 국방 정책은?',
#   "이스라엘 '장기전 대비' 병력 철수…확전 우려 지속",
#   '“카카오 경영진, ‘혁신’보다 ‘돈벌어 떠나자’ 생각하는 이 많아”[인사이드&인사이트]',
#   '평창 LPG 충전소 폭발 후 화재…2명 전신화상 등 5명 다쳐',
#   '영월 주천면 지방도 낙석 발생으로 전면통제',
#   '장병 정신-역사관 혼란 부른 軍 정신전력 강화 교재[손효주 기자의 국방이야기]',
#   '평창 LPG충전소서 가스 누출 연쇄 폭발…5명 중경상',
#   '일본 7.6 강진으로 피해 잇따라…2명 심폐정지 상태',
#   'NETHERLANDS NEW YEAR',
#   '“강원도청 지난해 수의계약 26%…1,100억 원”',
#   'CHINA CHINA CRUISE SHIP MAIDEN VOYAGE',
#   '동해시, 내일부터 한 달간 농업인수당 신청 접수',
#   '[바람개비]백업 골키퍼의 자신감',
#   '미스치프는 정말 성역 없는 예술을 할까?[영감 한 스푼]',
#   '마트에서 식자재 훔친 음식점 사장 ‘집행유예’',
#   '창원시, 2023년 제야의 종 타종행사',
#   '올해부터 부모급여·난임 지원 확대…달라지는 저출산·복지 정책',
#   '[신년사]허동식 밀양시장 권한대행, “새해 청룡의 기운으로 소망 이루시길”',
#   '[신년사]하승철 하동군수 "하동의 미래를 위해 모든 역량을 발휘하겠습니다"',
#   '동계청소년올림픽 선수촌 빈대 예방 등 점검 시행',
#   '北무기 안 쓴다더니…북한제 폭탄 든 러군, 방송에 버젓이 등장',
#   '대만 부총통 후보 TV 토론회…대중국 기조 두고 정면충돌',
#   '1월은 위기의 달이었다[임용한의 전쟁사]〈296〉',
#   '[고양이 눈]새해에도 파이팅!',
#   '강원도, 전통시장 활성화 부문 국비 16억 원 확보',
#   "새해 첫날 서울 마포서 '묻지마 흉기난동'…미국인 남성 체포",
#   '총선 승부처는? 쇄신 공천·수도권 싸움 ‘승패’',
#   '함양울산고속도로서 4중 추돌…1명 사망·4명 부상',
#   '경남 밀양분기점 인근서 4중 추돌…1명 사망 · 3명 경상',
#   '강원 정당 새해 인사…‘총선 승리’ 다짐',
#   "日 기상청 '쓰나미 주의보' 대상에 독도 포함해 표시",
#   '영월에서 낙석 발생...88번 지방도로 한때 전면 통제',
#   '아이를 낳아야 한다는 부담마저 사라지는 사회[2030세상/유재은]',
#   "'김건희 특검' 아닌 '도이치 특검' 표현한 한동훈 속내는?",
#   '‘겨울 산삼’이라 불리는 무의 3가지 효능[정세연의 음식처방]',
#   '‘현존 최장 52년 재임’ 덴마크 여왕 전격 퇴위 선언…이유는?',
#   '2024년 강원, 달라지는 제도·일상',
#   '‘노벨평화상’ 유누스, 노동법 위반으로 징역 6개월',
#   "양질의 한우 저렴하게...'빙온 숙성' 주목",
#   '평창 LPG 충전소 화재로 피해 입은 탱크로리',
#   '일본에서 규모 7.6 강진, 대형 쓰나미 경보…한국 동해안 피해 없어(종합)',
#   '평창 LPG 충전소 화재로 녹아버린 탱크로리',
#   '"스마트폰 3분이면 완료"...경기도, 무료 치매 검사 지원',
#   '인공지능 활용 119 신고 접수..."외국어 응대도 강화"',
#   '“돈 내는 게 맞긴 한데, 하...” 속만 썩이는 핀테크 업체들, 무슨 일',
#   '[출연] 22대 총선 D-100...여야 총선 행보 본격화',
#   '구름 속 해맞이 인파…‘제야의 종 타종식’',
#   "젤렌스키는 '강인하게', 푸틴은 '태연하게'..새해 대국민 메시지",
#   'SWITZERLAND NEW YEAR',
#   'SWITZERLAND NEW YEAR',
#   'SWITZERLAND NEW YEAR',
#   '평창 가스충전소 폭발 화재 현장',
#   '평창 가스충전소 폭발 화재 현장',
#   '평창 LPG 충전소 폭발 화재 진화',
#   '평창 가스충전소 폭발 화재…2명 전신화상 등 5명 중경상(종합)',
#   '평창 LPG 충전소 폭발 화재 진화',
#   '평창군 용평면 장평리 한 LPG가스충전소 폭발…5명 중경상',
#   "더나은에프엔비, 원주시 아이들 '건강식사'·'농업상생' 토토미 기부",
#   '이낙연 “국민께 양자택일 아닌 ‘새로운 선택지’ 드려야”',
#   '日 서부해안에 7.6 강진',
#   'PAKISTAN ELECTIONS',
#   'SWITZERLAND NEW YEAR',
#   'PAKISTAN ELECTIONS',
#   '“바닥이 출렁, 중심잡기가...” 한국인 관광객들 日강진 경험담',
#   '[신년사] 방세환 광주시장 “새해 맞아 광주시 미래를 여는 신성장 동력 사업 추진할 것”',
#   '행안부 “강원·경북 해안 지역 쓰나미 피해 없어”',
#   '日 신칸센 끊기고 3만가구 정전…밤새 여진',
#   '스위스 방송, 성추문 프랑스 국민배우 영화 편성표서 빼',
#   '주말엔 뭐하지? 도시 농부의 ‘겨울 블루’ 달랠 비책은…',
#   '평창 충전소서 가스 누출로 폭발사고…5명 중경상',
#   '건강버스 ‘부르릉’에 시골 어르신 “반갑당게”',
#   '30년 된 중부경찰서, 2029년 혁신도시에 신청사 건립',
#   '200년 지나도 설레…‘오만과 편견’ 작가는 그 서점에 갔을까',
#   '한국 조선, 지난해 수주 줄며 3년 연속 2위',
#   '차량등록사업소, 연초 폭증 민원 대비 30분 조기 근무',
#   'SWITZERLAND NEW YEAR',
#   '“잘 지내?” “그렇게 좋진 않아”…같은 게임 샀는데 내용 다르다고?',
#   '올해 울산 새해 첫 아기 새벽 0시에 태어나',
#   '어선 정박 상태 확인하는 해경',
#   '피해 방지 위해 총력',
#   '(FILE) DENMARK QUEEN MARGRETHE II',
#   '(FILE) DENMARK QUEEN MARGRETHE II',
#   '여야, 총선 앞으로…의회 권력 ‘탈환 vs 수성’ 사활',
#   '“아빠 장례비용 좀” 채팅서 만난 50대男에 2억 뜯은 30대女 징역형',
#   '이란 구축함 美 작전 중인 홍해 진입…긴장 고조',
#   '평창 LPG 충전소 폭발 후 화재로 5명 중경상… 목격주민 "땅이 흔들릴 정도의 폭발 발생"',
#   '日, 규모 4.3 지진 또 발생...한밤에도 계속 흔들렸다',
#   '군산 새만금방조제 주차장 텐트서 50대 남녀 숨진 채 발견',
#   '평창 LPG 충전소 가스 누출로 연쇄 폭발···5명 중경상',
#   '아이유, 복지 취약계층에 2억원 기부',
#   '2024년 주요 기관장들의 신년사는?',
#   '(FILE) DENMARK QUEEN MARGRETHE II',
#   'RUSSIA PUTIN',
#   'RUSSIA PUTIN',
#   'RUSSIA PUTIN',
#   '“땅 흔들릴 정도의 폭발”…평창 LPG 충전소 폭발로 5명 중경상',
#   '평창 가스충전소서 폭발 후 화재',
#   '평창 가스충전소서 폭발 후 화재',
#   '평창 가스충전소서 폭발 후 화재',
#   '전북 군산서 50대 2명 숨진 채 발견…“일산화탄소 중독 추정”',
#   '(FILE) DENMARK QUEEN MARGRETHE II',
#   '"LPG 충전소에서 가스 새고 있다" 땅 흔들리며 연쇄 폭발…5명 중경상',
#   'GERMANY SKI JUMPING',
#   'JAPAN EARTHQUAKE',
#   'GERMANY SKI JUMPING',
#   'JAPAN EARTHQUAKE',
#   "영화 '서울의 봄', 새해 첫날 1,200만 관객 돌파",
#   '해맞이 관광객 3만여 명 모여…첫해 구름에 가려',
#   'GERMANY SKI JUMPING',
#   'GERMANY SKI JUMPING',
#   'GERMANY SKI JUMPING',
#   'GERMANY SKI JUMPING',
#   '울산 새해 첫날 낮 최고 9.5도…내일 흐리고 2~11도',
#   'GERMANY SKI JUMPING',
#   'GERMANY SKI JUMPING',
#   '12년 난임, 첫 시험관에 “응애~”…첫둥이 ‘아홍이’ 기적 선물했다',
#   '평택시의회, 새해 현충탑 참배',
#   '김현기 서울시의회 의장, 2023년 제야의 종 타종',
#   '윤 대통령 “행동하는 정부 될 것”…‘국민·민생’ 강조',
#   '총선 D-100, 여야 지지율 초접전…한동훈·이재명 대권 경쟁도 치열',
#   '김정은, 딸 주애와 신년 경축공연 관람…당간부 연회',
#   '평창 LPG충전소서 연쇄 폭발...2명 심한 화상',
#   '총선 99일 앞으로… 4·10 총선 주요 일정은',
#   '‘이준석 신당’ 1월 중순 창당…“모든 것 바로잡을 방법 정치세력 교체에 있어”',
#   '"동해안 지진해일로 인한 인명피해 없어…비상대응반 운영"',
#   '日지진 2시간 뒤 韓 쓰나미 도달… 최고 높이는 67㎝',
#   'KDB산업은행 부행장에 삼척출신 서동호 선임',
#   '동해안 지진해일 관측 최고 67.0㎝…피해 없지만 안심 금물',
#   '경기도 남양주 부시장에 동해출신 홍지선 임명',
#   '김진태 지사, 금병산 정상에서 새해 첫 일출과 함께 새해 인사',
#   '기재부 재정성과심의관에 김명중 전 경제부지사 임명',
#   '[신년사]"강원특별법 3차 개정 심혈 도민과 함께하는 의정 최선"',
#   '[신년사]"과감한 정부 지원 이끌어 내 강원특별자치도 내실 다질 것"',
#   'JAPAN EARTHQUAKE',
#   '[신년사]"인구 200만·GRDP 100조원 미래 글로벌도시 도약 약속"',
#   '김진태 “2024년 내실 다져야…진정한 특별자치도 위상 세우겠다”',
#   '새해 첫날 日서 규모 7.6 강진…한신대지진보다 큰 규모',
#   '당뇨병성 신경병증 있을 때 심리사회적 치료 필요한 이유[밀당365]',
#   '태영건설 PF 대출보증 규모 9조원…채권단에 소집 통보',
#   "이 와중에도 '독도 억지'…日 기상청, 독도까지 쓰나미 경보",
#   '“살려줘” “도망가” 급박했던 당시 상황…日 강진에 아수라장 됐다(영상)',
#   '김현기 서울시의회 의장 "과감한 저출생 대책 모색 ‘서울의 존속’ 지켜내겠다"',
#   '일본 노토반도 규모 7.6 강진…현재 상황은',
#   '평창 LPG 충전소 폭발 · 화재로 5명 중경상…건물 14동 피해',
#   'RUSSIA PUTIN',
#   'AFGHANISTAN BUZKASHI',
#   'AFGHANISTAN BUZKASHI',
#   'AFGHANISTAN BUZKASHI',
#   "러·우크라, 새해 첫날도 교전…푸틴·젤렌스키 '승리' 자신(종합)",
#   'JAPAN EARTHQUAKE',
#   'JAPAN EARTHQUAKE',
#   '평창 LPG충전소 가스 누출 연쇄 폭발…5명 중경상',
#   '평창 LPG충전소 폭발 사고…1명 전신화상 등 4명 부상',
#   '日, 독도를 자국 영토인 양...쓰나미 주의보 지역에 넣었다',
#   "'우익 성향' 日 각료, 새해 첫날 야스쿠니신사 참배",
#   '“시민이 체감하는 큰 변화 만들 것”…박승원 광명시장 신년사',
#   '(4th LD) Small tsunamis hit S. Korea after earthquake in Japan',
#   '"2m 해일"…북, 일본 강진으로 함경북도 해안에 \'특급경보\' 발령',
#   '“반도체·AI·디지털전환 전문인력 양성에 집중할 것”',
#   '40년 전엔 10m 쓰나미...“日, 강진 여파 이게 끝 아니다”',
#   '日 강타한 지진에 도로 쩍쩍…"심폐정지, 매몰자 발생" 피해 늘 듯',
#   '[포토] 소비기한 표시제 본격 시행',
#   '동해안에 지진해일 도달…"24시간 이상 지속"',
#   '日서 규모 7.6 지진 발생…쓰나미 경보 발령',
#   '평창 LPG 충전소서 폭발 후 화재…불붙은 주변 건물들',
#   '“큰 싸움 벌일 것”…이낙연, 이재명과 만남 이틀만에 창당 선언',
#   '일본 강진 첫 인명피해 확인…"2명 심폐정지 상태로 발견"',
#   '서울시의회 김현기 의장  현충원 참배로 갑진년 새해 첫 일정 시작',
#   '새해 첫날 열도 강타한 日 강진…산사태·화재·도로 파손 등 이어져',
#   '중국 헝다 전기차 주식 매각 거래 종료',
#   '평창 LPG 충전소서 폭발 후 화재…불붙은 주변 건물들',
#   '평창 LPG 충전소서 폭발 후 화재…불붙은 주변 건물들',
#   '평창 가스충전소 폭발로 5명 사상…주민 대피령',
#   '이란 구축함, 홍해 진입...후티 교전 美와 긴장 고조',
#   '한동훈, 오는 3일 대한노인회 방문… 민경우 노인 비하 발언 논란 사과',
#   '되살아난 동일본대지진 공포…2011년 이후 첫 ‘대형 쓰나미 경보’',
#   '美대법원장 “AI, 법을 비인간적으로 만들 수 있어”',
#   '행안부 "동해안 지진해일 인명피해 없어…비상대응반 운영"',
#   "8만명 헛걸음 '드론쇼', 재공연도 20분 지각",
#   'RUSSIA PUTIN',
#   'RUSSIA PUTIN',
#   '軍, 새해 첫날 포사격 훈련... 신원식 “北 도발은 파멸 전주곡”',
#   '뉴진스, 연말 닫고 새해 열었다…美 ‘뉴 이어스 로킹 이브’ 장식',
#   '중국 자동차 회사 Geely, 2024년 판매 목표 190만대로 상향 조정',
#   '해운사 머스크, 예멘반군 위협에 홍해 운항 또 중단',
#   '한국 입국 거부됐던 ‘극우’ 日 각료, 야스쿠니신사 참배…외교부 “깊은 실망”',
#   '尹 신년사 “올 상반기 한미확장억제 완성해 북핵 봉쇄”',
#   "'독도는 일본 땅' 우기는 일본, 쓰나미 주의보 대상에 독도 포함",
#   '오리건 주간지, 횡령으로 전 직원 해고·인쇄 중단',
#   '[사설] 민생회복, 노동·연금·교육개혁 성과 내는 한 해를 기대한다',
#   '[사설] 北 “핵 대사변 준비” 봉쇄할 한·미 확장억제체제 완성 서둘라',
#   '[설왕설래] 세계 인구 80억명 시대',
#   '[채희창칼럼] 국정원이 간첩 수사 못한다니',
#   '[기자가만난세상] ‘오늘을 버티자’는 새해 목표 앞에서',
#   '새만금방조제 주차장 텐트 안에서 50대 남녀 숨진 채 발견',
#   '[WT논평] A Marxist version of Sodom and Gomorrah (1)',
#   '[박소란의시읽는마음] 아침은 생각한다',
#   '[한귀은의멜랑콜리아] 팬덤과 테러',
#   '[장은수의이책만은꼭] 삶의 주인으로 사는 법',
#   '갤럽, 한동훈 6070·영남 ‘강세’…이재명 4050·호남 ‘앞서’',
#   '\'평창 가스충전소 폭발 화재\' 전신화상 등 5명 부상…"접근 어려워"(상보)',
#   '이 와중에도…독도에 ‘쓰나미 주의보’ 내린 일본',
#   '[기고] 심화수학 없어도 개정 교육과정에 충실한 대입전형 설계 가능하다',
#   '일본 강진 여파, 묵호 67㎝ 해일…기상청 “24시간 지속될 수도”',
#   '중진공 11조원 예산 확정…‘납품발주서’로 자금대출 신규 편성',
#   '“중국에 수출? 오히려 적자”…20년만에 한국 최대수출국 된 미국',
#   '[부고] 김정애씨 별세 外',
#   "김정은, 딸 주애에게 공개석상서 '볼 뽀뽀'…가운데 입장도 양보",
#   '새해 불꽃놀이하다 독일서 2명 숨져…네덜란드선 차 폭발',
#   '연기 치솟는 평창 LPG 충전소 일대',
#   '이스라엘 "마지막 3단계 최소 6개월간 지속될 것"[이-팔 전쟁]',
#   '‘돌연 취소’ 광안리 드론쇼, 1일 오후에 재개',
#   '[인사] 중소벤처기업부 外',
#   "[단독]마포구 서교동서 '묻지마 칼부림'…미국 국적男 긴급체포",
#   '연기 치솟는 평창 LPG 충전소 일대',
#   "'서울의 봄' 1,200만 명 돌파...'태극기 휘날리며'도 제쳤다",
#   '8만명 헛걸음 광안리 드론쇼…1일 저녁에 열려(종합)',
#   '평창 LPG 충전소 가스 누출로 연쇄 폭발…5명 중경상(종합)',
#   '[2보] 평창 LPG 충전소 폭발 후 화재 부상자 5명으로 늘어…2명 전신화상',
#   '국방부 "독도 분쟁 지역"…일본, 쓰나미 주의보에 \'독도\' 자국영토 표기',
#   "올해는 '혜성' 관측의 해...2개의 혜성 온다",
#   '통신장애 돌연 취소 부산 광안리 드론쇼, 공연 재개도 20분 지연',
#   '강원도 평창군 용평면 LPG충전소에서 불…5명 부상',
#   '뉴욕에 100만 명 운집...런던 12,000발 불꽃놀이',
#   '새해 불꽃놀이 하다 독일서 2명 사망',
#   '경남 함양울산고속도로에서 4중 추돌사고…4명 사상',
#   '두 개의 전장, 새해 첫날부터 포성..."공습없는 하늘을"',
#   '“이란 구축함, 홍해 진입”…미-예멘 반군 교전 등 긴장 고조',
#   '"北 포탄 사용 버젓이"…러 방송사 천기누설?',
#   '“나라에 1억 넘게 벌어준 나, 애국자?”…불법주정차 2827번 신고 인증하자, ‘반응 폭발’',
#   '北, 핵 증강·위성 도발 예고..."상반기 한미 확장억제 완성"',
#   '北 김정은 "언제든 무력충돌 가능성"...딸 주애와 공연 관람',
#   '강원 평창 LPG충전소 폭발로 5명 중경상',
#   '부산시민 위해 평생 모은 수집품 공개한 김종신 해성아트베이 회장',
#   '일본 기상청 "오후 4~9시 진도 1 이상 여진 최소 59회 발생"',
#   '"대만, 中 침공 대비해 국제형사재판소 가입 검토"',
#   '日서 한신대지진보다 큰 규모 7.6 강진…한때 대형 쓰나미 경보(종합3보)',
#   '[인사] 한국마사회',
#   '최저임금 9860원...부모 모두 육아휴직하면 최대 3900만원',
#   '[포토] 성북구 2024 해맞이 행사',
#   "日 기상청 '쓰나미 주의보' 대상에 독도 포함해 표시",
#   '러 방송사 천기 누설..."우크라전서 러 병사들 北포탄 사용 보도"',
#   '영월에서 낙석 발생...88번 지방도로 한때 전면 통제',
#   '임산부 겪은 가장 불편한 경험은?..."직장 눈치와 길거리 흡연"',
#   '일본에 규모 7.6 강진…새해 첫날 ‘공포’',
#   "교사단체, '서이초 사건' 재수사 요구...'민원 의혹' 제기한 교사 소환조사",
#   '새해 잇따르는 주요 판결...이재용·양승태 운명은?',
#   "새해 불꽃놀이 하려다 '날벼락'…사고 속출",
#   '“생각보다 맵네?” 먹다남은 떡볶이 환불 요구한 손님…누리꾼들 공분',
#   '“7시간 벌벌 떨었는데…” 돌연 취소된 부산 광안리 드론쇼, 1일 오후에야 진행',
#   '[해양수산 소식] 항만 내 위험구역, 한 눈에 알아볼 수 있다外',
#   '日 이시카와현서 규모 7 넘는 강진…남북한에도 지진해일 경보',
#   '세입자 갱신 요구에 틀어진 계약..."잔금 지급 거절할 수도"',
#   "서울시, 내일부터 '안심소득' 참여 가구 모집",
#   "저렴하게 한 끼 해결...고물가에 늘어나는 '착한 가격'",
#   '최상목 "소상공인 126만 명 1인당 20만 원 전기요금 감면"',
#   '일본 강진 여파로… 동해 묵호항서 67㎝ 지진해일 관측',
#   '사과·배 과일 가격 강세...미국산 계란 112만 개 도입',
#   'HMM 모태 아세아상선 설립 주도 송윤재 전 고문 별세',
#   '北무기 수입 안한다더니…러 국영방송서 러시아군 사용 노출',
#   '[포토] 2024 신촌 카운트다운 콘서트',
#   '송미령 농식품부 장관 “산란계 농장 한층 강화된 방역 필요”',
#   '평창 LPG충전소 화재... 5명 중경상',
#   '춘천시, 동절기 노인복지시설 안전점검',
#   '기후연, 조직 개편…3실 1단 체제 도입',
#   '日 7.6 강진에 땅 꺼지고 가옥 붕괴…“쓰나미 위협, 대부분 지나가”',
#   '“강원도 지난해 수의계약 26%…1,100억 원”',
#   '마트에서 식자재 훔친 음식점 사장 ‘집유’',
#   "독도가 왜?…日 '쓰나미 주의보' 자국 영토에 버젓이 넣고 발표",
#   '고삐 풀린 기후변화…올해는 더 덥다?',
#   '강원 정당 새해 인사…‘총선 승리’ 다짐',
#   '“나라에 1억 벌어준 내가 애국자”…불법주차 2827건 신고 인증글 ‘눈길’',
#   '‘이선균 협박女’ 머그샷 공개될까?…올해부터 마약범죄 등 ‘중대범죄자’ 머그샷 공개',
#   "'쓰나미' 급박 상황에도..기어이 주의보에 독도 넣은 日",
#   '평창 가스충전소서 폭발 후 화재…2명 중상·3명 경상',
#   '[포토뉴스]7.6 지진 강타한 일본은 지금',
#   '이철규·이양수·권성동, 의정보고회 잇따라',
#   '평창 LPG 충전소 인근 도로에 자욱이 깔린 연기',
#   '[포토] 강북구 2024 해맞이 행사',
#   '2024년 강원, 달라지는 제도·일상',
#   '새해 불꽃놀이하다 독일서 2명 사망, 네덜란드선 차 폭발',
#   '이·팔 전쟁 계속…가자지구 보건부 "누적 사망자 2만1978명"',
#   '동해 묵호 최고 67cm까지 지진해일 높아져…“더 높아질 수 있다”(종합)',
#   '[속보] 일본 언론 “이시카와현 강진으로 2명 사망”',
#   '올해 농축산·식품 분야에 2,115억 원 투자',
#   '경산역 KTX 정차 하루 4회→6회 증편',
#   "가처분 소득 1%대 늘었는데...먹거리 물가 6%대 '껑충'",
#   '“수산물 방사능 검사 결과 적합”',
#   '나경원 "살아있는 여당 돼야…한동훈, 尹과 신뢰가 당정쇄신 자산"',
#   '동해 묵호 최고 67㎝ 지진해일…일본 강진 여파 속속 감지',
#   '한은 총재 "부동산PF 등 금융불안 철저 대비"',
#   '평창 LPG충전소서 폭발사고...2명 전신 화상 등 5명 부상',
#   '지난해 무역수지 적자 100억 달러 육박...반도체 개선 흐름',
#   '경북교육청, 울릉도에 독도교육원 건립 추진',
#   '밀양 분기점 부근 4중 추돌사고...1명 숨지고 3명 다쳐',
#   'GERMANY SKI JUMPING',
#   'GERMANY SKI JUMPING',
#   '대구·경북 섬유 수출 큰 폭 하락',
#   'GERMANY SKI JUMPING',
#   'epaselect MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   "왕실유물 감상하고 스탬프 여행…'국립고궁박물관 담다' 개편",
#   '딸 주애에 ‘볼뽀뽀’한 김정은...팔짱 끼고 애정 과시',
#   '평창 가스 충전소 폭발...4명 다치고 인근 지역 정전',
#   '대구문예진흥원, 경영본부장·대구미술관장 선임',
#   '오늘의 부고 - 2024년 1월 2일',
#   '오늘의 인사 - 2024년 1월 2일',
#   '지진 피해 지역을 보듬다…미야기 올레 ‘치유의 길’',
#   '대구 수성구, 문화특구 시범사업 선정',
#   '경기도형 원도심 도시재생 ‘더드림 재생사업’ 대상지 공모',
#   '사우디 국부펀드, 지난해 세계 국부 펀드 지출 4분의 1차지',
#   '대구 오피스텔, 상가 기준시가 큰 폭 하락',
#   '경기도, ‘체육인·농어민·기후행동·아동돌봄’ 기회소득 신설',
#   '경기지역 해맞이 행사서 빙판길 낙상 등 사고 잇따라',
#   '유정복 인천시장, 출산 정책 첫 수혜 신생아 축하 방문',
#   '인천 이동노동자 쉼터, 공존의 지혜',
#   '도성훈 인천교육감 신년사',
#   '“세계 무대서 평가받겠다”…올해 경기교육 비전은',
#   '“APEC·법원 유치 이뤄낼 것”…인천시장 신년사',
#   '브라질 페트로브라스, 세페티바 FPSO 생산 시작',
#   '새해를 알린 아기 울음소리…제주서 0시 0분 신생아 출산 화제',
#   '평창 LPG 충전소서 폭발 사고 후 화재',
#   '평창 LPG 충전소 폭발 후 화재로 4명 부상',
#   '“재정으로 지역 경기 부양”…김동연 경기지사 신년사',
#   '"중국 침공 가능성"…대만, ICC 가입 검토',
#   '영천 제2탄약창 일대 군사보호구역 해제',
#   '“제주 방문을 환영합니다”…첫 관광객 환영행사 열려',
#   '[제22대 국회의원선거] 충남 예비후보 38명 등록',
#   '다세대 주택 화재로 부자 숨져...멧돼지 습격에 주민 부상',
#   '이재명 "더 단합할 것"...이낙연 "기득권 세력과 한판승부"',
#   '평창 LPG 충전소서 폭발 사고 후 화재',
#   '“부동산 PF 위험 신호 감지”…이창용 한은 총재의 경고',
#   '우크라, "러 드론 87개 격추"…이틀간 양측 70명 사망',
#   '공사 비용 3년 새 30% 급등…건설 경기, 올해도 침체 지속',
#   '대구보건대-보건대병원-북구보건소, 협약 체결',
#   '르노코리아, 하이브리드 소형 SUV 시판',
#   'LG전자, CES에 글램핑용 ‘본보야지’ 업그레이드 버전 공개[포토뉴스]',
#   '[클로징]',
#   '태영건설, 워크아웃 신청 하루 만에 유동성 확보 약속 파기',
#   "취소 됐던 광안리 '새해맞이 드론쇼' 저녁에 열려",
#   '[제22대 국회의원선거] 세종 예비후보 11명 등록',
#   '‘푸른 용의 해’ 밝았다…새해 시민들 소망은?',
#   '2024년 새해가 밝았다!…제주 겨울 바다서 희망찬 새해 기원',
#   '박민영, 전 남친 논란 사과 "내내 후회…정신과 검사도"',
#   '계명문화대, 글로컬 직업교육 선도대학 면모 과시',
#   '평창 LPG충전소 폭발… 2명 심한 화상, 3명 경상',
#   "[속보]평창 LPG충전소 '폭발 사고' 1명 전신화상 등 4명 부상",
#   '외교부 “현재까지 일본 지진 관련 우리 국민 피해 접수 없어”',
#   '광주시교육청, 2028년 목표 신청사 건립 추진',
#   '충주시 농기센터, 새해 농업인 실용교육',
#   '평창 LPG 충전소서 폭발 사고·화재…1명 전신화상',
#   "황당한 일본 기상청 지도…버젓이 '독도는 일본땅, 쓰나미 조심'",
#   '“사법절차 악용해 재판 방해”…판사·배심원 분노 유발한 ‘제멋대로 50대’',
#   '보은군, 속리산 힐링아카데미단지 조성',
#   '[뉴스9 날씨] 내일 오전까지 중부에 눈·비',
#   '전남지역 ‘용’ 관련 지명 310곳…전국 최다',
#   '증평지역상품권 구매한도 30만 원으로 축소',
#   '대통령실 “尹대통령, 파리 기업총수 술자리 비용 ‘비공개’',
#   '평창 LPG 충전소서 폭발 사고 후 화재…2명 중상',
#   '춘천시 선별진료소 4년 만에 운영 종료',
#   '휴가 복귀 앞둔 군인, 전·의경에게 탕수육 무료로 주는 중식당',
#   '평창 LPG 충전소서 폭발 후 화재..전신화상 등 5명 중경상',
#   '한국무역협회 강원지역본부장에 한창회 UAE 지부장',
#   '미군, 후티 반군과 홍해서 첫 교전…"후티 쪽 고속정 3척 침몰"[\'중동 화약고\' 이스라엘-팔레스타인 분쟁]',
#   '영동 국악와인열차, 지난해 관광객 7천여 명 이용',
#   '일본 강진에 동해안 지진해일 주의…동해 묵호 최고 67㎝',
#   '한동훈 "동료 시민과 미래 만들 것"...이준석 창당 \'속도\'',
#   '폐지 수집 기부 80대…광산구 도산동서 온정 잇따라',
#   '총선·野 언급 없었지만..."이념 패거리 카르텔 타파"',
#   '반가워, 2024년![포토뉴스]',
#   '"중국 침공 가능성"…대만, 국제형사재판소 가입 검토',
#   '[신년사] 박정원 두산 회장 "투자는 미래 위한 도전…앞선 실행력 중요"',
#   'KBS청주, ‘새해 충북 민심 여론조사’ 발표',
#   '서서히 반등하는 반도체, 인공지능 붐 업고 봄 맞을까',
#   '“거문고 줄 고치듯”…‘변화’ 강조한 최태원',
#   '금감원장 “부실기업 자기책임 원칙 엄수”',
#   '일본 기상청, 쓰나미 주의보 지역에 독도 버젓이 포함',
#   '올해 세계 경제 3대 위험요소는... “①미국 금리 ③중국 저성장 ③엘니뇨”',
#   '‘인구감소’ 지역, 주민보다 ‘머물다 간 사람’이 더 많았다',
#   "발 차가워 수면양말 신었는데… 생각지도 못한 '이 병' 걸렸다",
#   '자회사서 3.2조 중간배당…한전, 채권 10조 추가발행 여력 생겨',
#   '잃어버렸던 내 동심, ‘이곳’ 가면 충전할 수 있다…서울 나들이 스폿 2',
#   "황당한 日기상청, 독도에 '지진해일 주의보' 발령",
#   '\'민생\'만 9번 외친 尹..."행동하는 정부, 따뜻한 정부"',
#   "'열정 가득' 새해를 힘차게 시작한 사람들",
#   '“여행 지출액 절반 환급”…강진군, ‘반값 관광의 해’ 추진',
#   '충북 교권보호위 등 학교업무 교육청 이관',
#   '마라도함에서 만난 올해 첫 일출',
#   '충청북도, 노인 일자리 확대',
#   '민주, 尹 ‘패거리 카르텔’ 발언에 “척결해야 할 건 친윤 카르텔”',
#   '러 푸틴, 새해 첫날 "우크라 군사 시설 공격 강화할 것" 강조',
#   '남해안 해맞이 명소 \'북적\'..."올해는 평화가 찾아오길"',
#   '에너지 분야 ‘한국판 실리콘밸리’ 꿈꾸는 전남',
#   '금산군 양수발전소 유치 성공…경제활성화 기대',
#   '해돋이는 구름에 가렸지만..."가족과 함께해 행복"',
#   '日 강진 여파로 동해 묵호에 67㎝ 해일…강원도 소방 비상 대응 1단계 발령',
#   '"원하는 바 이루길"...힘차게 시작한 2024년',
#   '한동훈 국민의힘 비대위원장, 내일 대전 방문',
#   '‘선거법 위반’ 등 경남 단체장, 새해 결심·선고 잇따라',
#   '더불어민주당 지도부 봉하마을 노 전 대통령 묘역 참배',
#   '[1보] 평창 LPG 충전소에서 폭발 후 화재로 4명 부상',
#   '러시아, 사할린섬·블라디보스토크에 쓰나미 경보',
#   '22대 총선 D-100, 충청권 표심 향배 관심',
#   "日, 쓰나미 주의보 대상에 '독도' 포함",
#   '박완수 지사·박종훈 교육감 등 단체장, 충혼탑 참배',
#   "日 새해 첫날 7.6 강진…13년만이 '대형 쓰나미 경보' 발령",
#   '갑진년은 ‘청룡의 해’…용의 기운 담은 지명 어디?',
#   "1월 1일 '뉴스 9' 클로징",
#   '[날씨] 2일 오전까지 중부 눈·비 조금…동해안 안전사고 유의',
#   '2024 경남, 새해 달라지는 것은?',
#   '치열하고 겸손하게, 무너지지 않도록[경향 신춘문예 문학평론 부문 당선소감]',
#   '[윤정호의 오늘] 다시 날자, 대한민국',
#   '동해안에도 지진해일 여파...동해 묵호 최고 67cm',
#   '4월 총선 때 전북 2곳 도의원 재보궐 선거',
#   '기술보증기금, 기후기술기업 우대 보증 상품 출시',
#   '‘상실’에서 ‘윤리’로…천선란 SF의 ‘다종적’ 얽힘 유려하게 짚어내[경향 신춘문예 문학평론 부문 심사평]',
#   '“전북 근로자, 일·생활 균형 수준 전국 하위권”',
#   '평창 LPG 충전소서 폭발 사고 후 화재',
#   '전라북도, 새해 바이오 등 미래 성장산업 관련 기업 유치',
#   '부산 시티투어버스 10일부터 일부 노선 운영 재개',
#   '여야 정치권 내일 부산서 ‘총선 승리’ 다짐',
#   '러 방송사 천기누설…"북한포탄, 우크라전 영상에 버젓이"',
#   '부산대 인근서 흉기 소지·위협 20대 남성 검거',
#   '"웃돈 주고 방 잡았는데 취소"…\'부산 드론쇼\' 뒤늦게 열렸다',
#   '“부산 해수면 변동 0.2m 미만”…해안가 주의',
#   '전북특별자치도 출범…“독자 권역 생존 전략”',
#   '日, 새해 첫 날 규모 7.6 강진...대형 쓰나미 경보',
#   '[미리보는 이데일리 신문]“상생금융·PF 관리” 지주회장 한목소리',
#   '24시간 어린이병원 확대…올해 바뀌는 것은?',
#   '상실의 자리로부터-천선란론[2024 경향 신춘문예 당선작 - 문학평론 부문 정우주]',
#   '20년여만에 뒤바뀐 무역판도…월간 대미 수출, 대중 수출 제쳤다\xa0',
#   '올해 브릭스·CIS 이끄는 푸틴 대통령 "다자주의 강화"',
#   '평창 용평면 가스충전소 화재…전신화상 등 4명 부상',
#   '\'현존 최강\' 아파치 헬기 직접 타보니…"암흑의 도살자"',
#   '러 외무 "특별군사작전 목표 달성 뒤 우크라 정권 처벌"',
#   '평창 가스 충전소 폭발...4명 다치고 인근 지역 정전',
#   '이철우 도지사 신년사 "우리 스스로 기회를 만들자"',
#   '주일한국대사관 "일본 강진으로 교민 인명피해 현재까지 없어"',
#   '경북도, 야간 및 휴일 소아청소년과 응급실 확대 운영',
#   '밀양 분기점 부근 4중 추돌사고...1명 숨지고 3명 다쳐',
#   '40년 전 오늘, 전 세계가 놀랐다…백남준 ‘굿모닝 미스터 오웰’',
#   '평창 LPG 충전소 폭발 사고…전신화상 등 4명 부상',
#   '홍해 진입한 이란 구축함…美와 긴장 고조',
#   '北, 김정은 육성 보도하며 배경에 \'한미일 정상회의\' 사진…"언제든 무력충돌"',
#   'KBS광주, 총선 여론조사 내일부터 공개',
#   '“군 간부 1인 1실”…달라지는 국방 정책은?',
#   '홍해 진입한 이란 구축함…美와 긴장 고조',
#   '클로징',
#   "100년 만의 '파리 올림픽'…지구촌 포용의 장으로",
#   '“발걸음 참 무겁네요” 새해 밝았지만…자동차·철강·IT 회사들 ‘불안불안’',
#   '2024 해맞이 명소 ‘북적’…“새해 새출발 다짐”',
#   '"숙련공으로 키워요"…\'뿌리산업\' 지탱하는 외국인들',
#   '2024 새해 밝았다!…경남 해맞이 명소 북적',
#   '2024년 새해 밝았다…충북 해맞이 인파 ‘북적’',
#   '日 규모 7.6 지진…포항에도 지진해일 도달',
#   '갑진년 ‘청룡의 해’…새해 첫날 해맞이 명소 북적',
#   '새해 맞이 ‘제야의 종’ 타종식 강원 내 시군별로 열려',
#   '달빛철도법·군공항 이전…해 넘긴 숙제들',
#   '올해부터 부모급여·난임 지원 확대…달라지는 저출산·복지 정책',
#   '기상청 “일본 지진, 전남 남해안 피해 없어”',
#   '한국도 \'다인종 국가\'…"기반다져 후배 외국인 정착 돕죠"',
#   '[신년사] 이창용 "부동산 PF 위험신호 감지...금융불안 가능성에 대비해야"',
#   '[MediaZ] “도로교통법 미적용”... 캠퍼스 내 이동로는 ‘안전 사각지대’',
#   '“독도 쓰나미 조심”…日, 쓰나미 주의보 발령 지역에 또 독도 포함',
#   '[영상] 한라산에 떠오른 2024년 첫해',
#   '2024년 밝았다…‘힘찬 새해 기원!’',
#   '김영록 전남지사 "갑진년 \'세계로 웅비, 전남 행복시대\' 열 것',
#   '재위 52년 앞둔 덴마크 여왕, 신년사 중 “퇴위” 깜짝 발표',
#   '시진핑 “통일은 역사적 필연” 신년사…대만 총통 선거 앞두고 주목',
#   '“대기인원만 30명, 식사 끝난 손님 30분째 수다”…권리 vs 민폐',
#   '미군, 홍해에서 후티 반군과 첫 직접 교전…최소 10명 사살',
#   '[신년사] 김병수 김포시장 “갑진년은 김포-서울통합, 5호선 김포 연장 등 결정짓는 한 해 될 것”',
#   "겨울 바다에 '풍덩'…이색 체험으로 새해맞이",
#   '평창 LPG충전소에서 화재 발생…2명 전신화상·3명 부상',
#   '집 팔았는데 \'전세 갱신\' 요구…대법 "집주인이 책임져야"',
#   '평창 LPG 충전소서 화재 1명 전신화상…추가 폭발 위험도',
#   '2024년 새해 밝았다…광주·전남서도 해맞이 행사 잇따라',
#   '하마스, 새해부터 로켓 공격…격화되는 우크라 전쟁',
#   '해수부, 설 앞두고 선원 임금체불 특별근로감독',
#   "흉악범 '머그샷' 공개…동창도 몰라본 '정유정 사진' 사라진다",
#   "[국가고객만족도 NCSI 조사]삼성물산, '래미안 헤스티아'로 입주민 경험 차별화",
#   '[신년사] 안성환 광명시의회 의장',
#   '[국가고객만족도 NCSI 조사]롯데免, 글로벌 면세시장 공략 위한 외연 확장 가속화!',
#   "'자기네 땅도 아닌데'...독도에 해일주의보 내린 일본",
#   '고양서 60대 다방 주인 숨진 채 발견…경찰, 용의자 추적',
#   '[그래픽] 일본 이시카와현 지진 발생(종합)',
#   '올해 브릭스·CIS 이끄는 푸틴 "다자주의 확대 방점"',
#   '미·중 관계, 새해엔?…“선거 앞두고 경제 갈등 심화”',
#   'AUSTRALIA TENNIS',
#   '규모 7.6 강진 日, 쓰나미 주의보 지역에 독도까지 포함해',
#   '\'연예인 앞세운\' 車 리스업체 돌연 폐업…피해자들 "사기"',
#   '경북도, 소아청소년과 응급실 4곳 추가',
#   '[국가고객만족도 NCSI 조사]디지털 기반 글로벌 금융기업 지향',
#   'epaselect MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   '“취업 지원·임대주택 건립”…‘청년 모시기’ 나서는 충북 영동군',
#   '"지금 사야 돼" 사라진 명품 \'오픈런\' 다시?…새해 벽두 줄줄이 인상설',
#   '난임 지원 확대·자연재해 보험, 올해의 ‘기대주’ 지자체 정책들',
#   '[국가고객만족도 NCSI 조사]교육·운송 등 4개 부문 상승…전년 11개 대비 줄어',
#   '‘포스트 코로나 건강 주의보’…남성 허리둘레 5년새 1㎝ 늘었다',
#   '경기도, ‘체육인·농어민·기후행동·아동돌봄’ 기회소득 신설',
#   '"독도 쓰나미 조심하세요"…日, 자국 영토로 표시하고 경보 발령',
#   '일본 기상청 “독도는 일본땅”…쓰나미주의보 대상에 독도 포함',
#   '日, 중북부 규모 7.6 강진…"건물 무너지고 쓰나미 경보"',
#   '[날씨] 흐린 새해 첫 출근길…빙판길·도로 살얼음 유의',
#   '러, 전쟁 다음은…"우크라 정권 처벌"',
#   '일본 쓰나미 특보에 독도가 왜? 재난중에도 억지 주장',
#   '평창 LPG 충전소서 폭발 사고 후 화재…1명 전신화상',
#   '고속도로 지하화 속도…상부는 공원으로, 상습 정체 해소도',
#   '한쪽은 폭죽·한쪽은 포성…지구촌 같은날 다른 새해 풍경',
#   '[포토] “안 오른게 없네”… 작년 먹거리 물가 6.8% 상승',
#   '우크라 의무병 나섰던 英 20대 여성, 성탄 이브에 숨진 채 발견',
#   '1인 가구 노인 ‘월 소득 213만원 이하’면 기초연금 받는다',
#   '“구름 헤치고 뜬 해처럼…결국 이루는 해 되길”',
#   '2024년 1월 2일 흐린 하늘…큰 추위 없어요[오늘의 날씨]',
#   '미중 정상, 수교 45주년 축전 교환… "양국 관계 발전" 한목소리',
#   '“내 배, 언제 이렇게 나온 거지?” 남성 허리둘레 5년 새 0.9cm 늘어',
#   '쓰레기 더미 위에 ‘꿈’을 심다...‘바세코’에 전한 희망',
#   "일본 덮친 7.6 강진에 건물들 '와르르'…큰 위협은 지나간 듯",
#   'SRI LANKA ECONOMY TAX',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   '“北 도발에 강력 응징” 새해 첫날 포사격 훈련',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   '위기의 기시다, 신년사서 “국민 신뢰 회복하겠다”…비자금 스캔들 돌파 의지',
#   '‘남조선 평정’ 선언한 김정은, 시진핑과는 축전 “조중 친선의 해”',
#   '새해둥이는 12년 만에 얻은 아기…"난임 부부 응원해요"',
#   '대기업·중소기업 노동시간 격차, 이제야 겨우 좁혀가고 있는데…',
#   '청년들 주 15~40시간 일할 때 삶과 직무 만족도 가장 높은데…',
#   '동해안 지진 해일 시작…기상청 "24시간 이상 지속"',
#   '아파트 샀는데 세입자 ‘계약갱신’ 요구 땐?',
#   '현직 검사 잇단 총선 행보…못 말리나요, 안 말리나요',
#   '갑진년 용띠들의 새해소망... “청룡의 기운으로 풍요롭길”',
#   "트럼프부터 신냉전까지…새해 지구촌 '10대 화두'",
#   '총선 승부처는? 쇄신 공천·수도권 싸움 ‘승패’',
#   '이스리엘군, 5개 여단 가자서 빼내… "헤즈볼라 전선으로"',
#   '조국 "대통령실 학폭 터진 날, 공교롭게 이선균 수사 착수"',
#   '구름에 숨은 \'청룡의 해\' 첫 일출…"아쉽지만 좋은 일만 가득하길"',
#   '‘도전과 변화’ 푸른 용의 해 활짝... 2024년 새해 첫 표정',
#   "미 대선 윤곽은 '아직'…민주당-공화당 경선 일정은?",
#   '올해 47개국 선거 역대 최다…경제·안보 새 판 짜여진다',
#   '강기정 광주시장 "올해 더 많은 기회, 더 좋은 광주 열 것"',
#   '여야, 총선 앞으로…의회 권력 ‘탈환 vs 수성’ 사활',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   'SRI LANKA ECONOMY TAX',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   '[포토] 겨울엔 역시 송어 얼음낚시',
#   '인기 없는 바이든 vs 자격 없는 트럼프',
#   '이시카와현에서 발생한 지진 관련 기자회견',
#   '[뉴스하이킥] "\'돈\' 앞에서 어떻게 살 것인가".. \'황금종이\' 조정래 작가가 던지는 질문',
#   '반도체·자동차가 반등 이끈다…3년 만에 무역흑자 기대',
#   '지진으로 갈라진 도로',
#   '이시카와현에서 발생한 화재',
#   '지진으로 무너진 가옥',
#   '가나자와시 오노히요시 신사 지진 피해',
#   '"대만, 중국 침공 대비해 국제형사재판소 가입 검토"',
#   '2024년 우리의 정치·경제·사회는? [여론조사]',
#   '조국이 공유한 성명서...“공교롭게도 대통령실 학폭 터진 날, 이선균 수사 착수 발표”',
#   '[포토] 새해 첫날 日서 규모 7.6 강진',
#   '홍해 한복판서 미군-예멘 반군 첫 교전…10명 사망',
#   '소비심리 여전히 겨울이지만…자영업자들 "봄날 왔으면"',
#   '여수세계섬박람회 천 억 규모로 개최.."정부도 적극 지원"',
#   '[날씨] \'강진 영향\' 동해안 풍랑특보…"해안가 접근 자제"',
#   "4월 총선 '정부 견제론', '정부 지원론'에 10~12%p 앞서[코리아리서치·입소스]",
#   "건물 무너지고 도로 쩍쩍 갈라졌다…日 뒤흔든 '7.6 강진'",
#   '신생아 특례대출·주거비 지원..새해 달라지는 시책은?',
#   '동해 묵호항 67cm 지진해일 관측…日 지진 여파',
#   "이란 구축함, 홍해 진입…'수호자 작전' 美와 긴장 고조",
#   '[희망2024]22대 총선 민주당 텃밭에 제3지대 신당 바람 일까?',
#   '2024년 \'청룡의 해\'..시·도민 "용처럼 풍요롭고 기운차게!"',
#   '“김정은, 핵 제한 전제로 한 대화 무관심…치명적 도발 가능성”',
#   '한국, 올해부터 2년간 ‘유엔 안보리 비상임이사국’',
#   '김정은 지시 따라…북, 외무상 최선희 주도로 대남 사업 기구 정리 착수',
#   '갑진년 첫 해맞이.."새해 행복·건강 기원"',
#   '이낙연, 행주산성서 "큰 싸움 벌일 것"…이준석, 尹겨냥 "뜻대로 안되면 카르텔 지목"',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   '김정은 “언제든 무력 충돌 생길 수 있어”',
#   '"건강합니다"…나이지리아 피랍 근로자 2명 무사 귀환',
#   '광주시교육청, 교육부 재정집행률 목표 2년 연속 달성',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   '유승민 "이대로 가면 나라 망해…권력의 졸개 노릇하며 대통령에 \'찍소리\' 못해"',
#   '차기 대선주자 이재명 27%, 한동훈 22%…4050은 이재명, 6070은 한동훈',
#   '이재명, DJ·盧 참배 "더 단합할 것"…\'尹신년회 불참\'으로 기류 바뀌어',
#   '윤 대통령 “행동하는 정부 될 것”…‘국민·민생’ 강조',
#   '日 대중음악 완전 개방 20년…K팝이 더 뜨거웠다',
#   '해수부, 패류독소 안전관리 강화…생산해역 120곳서 조사',
#   '새해 첫 출근길 곳곳 눈·비…낮 최고 11도',
#   '한동훈 "연평도 포격 때 쉴 곳 제공한 찜질방 사장님처럼…동료 의식 실천"',
#   '정의당·녹색당  “낡은 정치구도 바꿔야”',
#   '총선 모드 국민의힘…한동훈표 정치 구체화',
#   "광주신세계 '푸른 용의 해' 용 새긴 골드바 선봬",
#   '딸 주애와 친밀감 과시…김정은, 대남기구 정리 착수',
#   '새해 맞는 지구촌…한결같은 소망은 ‘평화’',
#   '‘개혁 보수 신당’ 계획 공유한 이준석 “나를 뺀 여당, 도로 자유한국당”',
#   '尹 "이권·이념 기반 \'패거리 카르텔\' 반드시 타파"…이달 신년 기자회견 검토',
#   '금가는 민주당…이재명 ‘정통성’으로 돌파구',
#   "대구시 '국립치의학연구원' 유치 본격화, 산업 클러스터 구축 시너지↑",
#   "지방공공기관 채용시험에도 공인 어학 성적 '최대 5년' 인정",
#   '‘20대 무당층’ 총선 승패 가르나…남성 이탈 큰 폭 증가',
#   '[총선설명서 서반장 vs 김반장] ② ARS 조사의 착시',
#   '[총선설명서 서반장 vs 김반장] ① 떠나간 尹心 어디로',
#   '"\'도이치\' 검사 지원 안 했는데 해외발령"…법무부 "허위 사실"',
#   '저출산 예산에 280조 원 쏟아부었는데…어디로 갔나',
#   '“중년여성 찾습니다” ‘대변 테러’ 당한 자영업자의 호소',
#   '“올해는 부디”…2024 시민들의 바람',
#   '일본 강진에 동해안 지진해일 관측…묵호 최고 67㎝(종합2보)',
#   '[포토] “눈썰매 신나요”',
#   '[단독]“태영그룹, 워크아웃 신청 하루 만에 ‘유동성 확보’ 약속 어겼다”',
#   '일본서 규모 7.6 강진‥대형 쓰나미 경보 발령',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   'BANGLADESH JUSTICE',
#   'BANGLADESH JUSTICE',
#   '"도이치모터스 수사검사 지원 안했는데 해외발령"…법무부 "허위 사실"',
#   'BANGLADESH JUSTICE',
#   '새해가 내미는 따뜻한 손… 서로 믿고 보살피게 하소서 [청룡처럼 비상하라 - 2024 신년시화]',
#   '‘신도 성폭행’ 이재록 목사, 형집행정지 중 사망',
#   "韓 입국 거절됐던 '극우' 日 각료, 새해 첫날 야스쿠니신사 참배",
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   'MIDEAST ISRAEL PALESTINIAN CONFLICT',
#   '신춘문예 - 소설 [2024 신년기획]',
#   '[밀착카메라] "나뿐 아니라 다 같이 잘 되길" 시민들의 새해 소망은',
#   '설레는 새해 첫 순간들…“더 행복한 새해가 되길”',
#   "맨몸으로 '풍덩'.. 새해 '무사안녕'  기원",
#   '홀로사는 65세 이상, 월소득 213만원 이하면 기초연금 받는다',
#   '김정은, 시진핑과 축전 교환… “2024년은 조·중 친선의 해”',
#   '20대 영국女의 안타까운 죽음…우크라서 전투의무병 봉사하다 성탄절 이브날 숨진채 발견',
#   '"제주도민 여러분, 새해 복 많이  받으세요"',
#   '‘독도’를 버젓이…씁쓸함 자아내는 일본 기상청 쓰나미 지도',
#   '김정은 “통일 불가” 구체화… 대남사업 기구 정리 착수',
#   '일본 해상서 규모 7.6 강진 발생… 높이 5m 쓰나미',
#   '신춘문예 - 시 [2024 신년기획]',
#   "제주 바다 수호하는 희망의 상징  '용'",
#   '새해 첫날, 도내 첫 용띠해 아기  탄생',
#   '주요 기관장 새해 첫날 공식 일정 시작',
#   '총선 100일 앞으로, 주요 정당 새해 일정  시작',
#   '코로나19 선별진료소, 오늘부터 운영  중단',
#   '제주종합경기장 문화 공연 장소로  활용',
#   '동해안, 31년 만의 지진해일…앞으로 영향은?',
#   "수산물 방사능 검사  '적합'",
#   '새해맞아 화재 안전 긴급  점검',
#   '최상목 "소상공인 1인당 전기료 20만원 감면"',
#   '[신년사] 경기도의회 민주 남종섭 대표의원 "도민과 함께 농부의 마음으로 희망의 밭을 일궈 나갈 것"',
#   "카운트다운 외쳤지만 '조용'…'광안리 드론 쇼'에 무슨 일이",
#   '총선 ‘정부 견제론’ 높지만 민주당 지지율로 안 이어져',
#   '제주 첫 단설유치원 9월 설립  전망',
#   '\'86세대 퇴진론\' 찬성 58%…"尹, 김건희 특검 거부 말아야" 63%',
#   '줄설 때 ‘짝다리’… 골반 불균형 유발, 척추질환 가능성도',
#   '신춘문예 - 평론 [2024 신년기획]',
#   '"어젯밤 했더라면" 광안리 8만 인파 실망시킨 \'청룡 드론쇼\' 1일 저녁 재개',
#   '오후 7시 17분 지진해일 도달…이 시각 포항',
#   '"출산 강요는 폭력"…출산 꺼리는 세대의 이야기, 직접 들어보니',
#   '갑진년 해맞이…청룡 기운에 저마다 소원 담아',
#   '울진 주택 화재로 부자 사망…경주 교통사고로 1명 사망',
#   '2024년 대학 등록금 인상이냐, 동결이냐?',
#   '\'이별예감\' 속 봉하 찾은 이재명 "단합"…이낙연은 "새 선택지"',
#   '한동훈 "\'동료의식\' 실천하는 당 만들 것"…이준석, 이달 중순 창당 마무리',
#   '탕후루 많이 먹다간 비싸게 심은 임플란트 빠질수도',
#   '동해안 지진해일 ‘초긴장’…“안심 금물”',
#   "1월 1일 '뉴스 9' 헤드라인",
#   "'차기대선 양자대결' 이재명 38%·한동훈 38%…서울 韓, 인천·경기 李 우세",
#   '유럽문화 한가운데서 ‘K컬처’ 띄운다 [2024 신년기획-파리올림픽]',
#   '경제계, ‘민생 강조’ 대통령 신년사에 일제히 환영',
#   '이선균 협박 덮으려고? 친했던 유흥업소 女실장 마약 투약 제보한 윗집녀',
#   '2023년 물가상승률 3.6%로 마무리… 2024년 ‘2.6% 전망’ 실현될까',
#   '“긁을수록 더 가려운 고통… 더 번지기 전 초기에 잡아야”',
#   '새해부터 수산정책자금 공급규모 7000억 원 확대…어업경영자금 대출한도 5억 원 상향',
#   '구름 뚫고 나온 새해...한라산 백록담 장엄한 일출',
#   '10명 중 6명만 ‘결혼 필수’ … 안 하는 이유 1위 “돈이 부족해서”',
#   '지진해일 불안 ‘여전’…노토반도는 어떤 곳?',
#   '“자꾸 우기네” 日, 쓰나미 주의보에 ‘독도 일본땅’ 표기',
#   "이준석 '개혁신당' 이달 중순 창당…여 문병호 합류(종합)",
#   '강원 동계청소년올림픽 G-17, 대회 준비 박차',
#   '"신년 기대감 없다"…소상공인·전통시장 전망경기 \'찬바람\'',
#   '"가족들 공격받아" 14살 소년의 신고…드러난 혐의에 미 \'충격\'',
#   '北 “함경북도 청진에 2ｍ 쓰나미”… 특급경보 발령',
#   '日 "독도는 일본땅"…쓰나미 주의보 지역에 독도 포함',
#   '예능·드라마서 맹활약…2023 연말 시상식 빛낸 강원 출신 방송인',
#   "'내일 총선이면' 與 33%, 野 33%…'與 심판론' 60%",
#   '새해 첫날, 일 노토반도에 규모 7.6 강진…구조 요청도 잇따라',
#   '전설이길 사양한 아재들의 야구 [김선걸 칼럼]',
#   '자국 기업 ‘중복 규제’가 글로벌 트렌드? [취재수첩]',
#   '0%에 화들짝 놀란 삼성 반도체 직원들 [재계 TALK TALK]',
#   '살길 해외뿐인데…‘빨간불’ 마주한 카카오모빌리티 [재계 TALK TALK]',
#   '태영건설, 결국 워크아웃…PF ‘빚 폭탄’ 다음은 어디? 건설업계 ‘시끌시끌’ [재계 TALK TALK]',
#   '‘잭팟’에서 골칫거리로 전락한 폴란드 방산 수출 [재계 TALK TALK]',
#   "'피프티 피프티' 퇴출된 前 멤버 3명, 새 소속사 찾는다",
#   '[영상] 2024 희망찬 새해',
#   '지난해 하반기 들어 수출 회복세…"새해 반도체 실적 늘 것"',
#   '“尹 잘한다” 36%… 중도층 지지율 하락폭 커',
#   '“김건희 특검 거부권 반대” 63%… “총선 이후 특검” 55%',
#   '“집에서 감자칩 먹고 싶어요” 가자지구 7세 소녀 소박한 꿈',
#   "첫 지자체 주도 온종일 돌봄 '화천커뮤니티센터'\u2008관심\u2008폭발",
#   '“올핸 외면 말고 들어주세요…힘든 이들의 간절한 외침을”',
#   '독도에 쓰나미 주의보 발령한 日…사실상 자국 땅 표기',
#   '일본 지진 여파 동해안 한때 지진 해일 긴장',
#   '국힘 33% vs 민주 33%...총선 지지도 막상막하',
#   'GERMANY NEW YEAR 2024',
#   'GERMANY NEW YEAR 2024',
#   'GERMANY NEW YEAR 2024',
#   '日서 새해 첫날 규모 7.6 강진…기상청 "동해안 지역 지진 해일 유의"',
#   '‘여신도 성폭행’ 이재록 목사, 형 집행정지 중 사망',
#   '이낙연 "국민께 양자택일 아닌 새로운 선택지 드려야" 신당 공식화',
#   '12월 대미 수출, 대중 수출 추월…중국 경기악화 영향',
#   '日 지진 여파…강원 묵호에 높이 67㎝ 지진해일 관측',
#   '"금리 떨어질 듯" 예상 속속…새해 부동산 시장 전망은?',
#   '"평범한 일상" 바라는 건 그뿐인데…소망 비웃듯 쏟아진 폭격',
#   '윤 대통령 “패거리 카르텔 타파”…새해 국정도 다시 ‘이념 앞으로’',
#   '‘지진해일! 도망가!’…日 강진에 건물 무너지고 대형 화재 발생',
#   "가처분 소득 1%대 늘었는데...먹거리 물가 6%대 '껑충'",
#   '“실물 ‘사진’까지 등장” 삼성 난리난 ‘최고폰’ 유출 알고보니…실수?',
#   '혐의만 100여개…노벨평화상 수상자에게 무슨 일이?',
#   '“미·일 다음 중국과 협력? 순진한 발상”[신년 인터뷰]',
#   '上上, 현실이 되나',
#   '한 달 수익률 16.7%… 다시 살아나는 바이오',
#   '일본 7.6 강진…동일본 대지진 이후 첫 대규모 쓰나미 경보(종합2보)',
#   "'독도는 일본땅' 우기는 日, 쓰나미 주의보 대상에도 독도 포함",
#   "고금리·고물가 난제…올해 '내수 훈풍' 언제 불까?",
#   'PAKISTAN ELECTION',
#   '카운트다운 외치며 "해피 뉴 이어"…전 세계 곳곳 불꽃놀이',
#   '스마트폰 앱서 만난 50대 남성에 2억 뜯어낸 30대 여성',
#   '광복회 "이완용 두둔도…독도 파문, 신원식 국방 친일인식 때문"',
#   '\'이념\' 다시 꺼내든 윤 대통령 "패거리 카르텔 반드시 타파"',
#   '뉴스데스크 클로징',
#   "'1km' 세계 최고층 빌딩 건설…삼성·현대·대우 불참 확정",
#   'PAKISTAN ELECTION',
#   'UKRAINE RUSSIA CONFLICT',
#   '[야고부] 용문점액 vs 등용문',
#   'UKRAINE RUSSIA CONFLICT',
#   'UKRAINE RUSSIA CONFLICT',
#   '[세풍] ‘나쁜 놈들 전성시대’',
#   "'무인도 표류 땐 미키마우스를 그려라'? 이젠 모두의 미키로",
#   '[단독] 해외 자원개발 길 터준다…실패해도 원리금 상환 부담 낮춰줘',
#   "신칸센 멈춰서고 3만6000가구 정전…도쿄까지 '흔들'",
#   'PAKISTAN ELECTION',
#   'PAKISTAN ELECTION',
#   "[날씨] 중부 눈·비 조금, 도로 살얼음 조심‥내일 미세먼지 '좋음~보통'",
#   'PAKISTAN ELECTION',
#   'epaselect UKRAINE RUSSIA CONFLICT',
#   'PAKISTAN ELECTION',
#   '핵 도발로 대선판 흔드는 북한…미 정부 "대화 추구" 되풀이',
#   '윤 대통령 신년사 "카르텔 타파…행동하는 정부 될 것"',
#   '강원 묵호 지진해일 예상보다 높은 67cm…"24시간 이상 지속될 수도"',
#   '“편의점에서 이런걸 판다고요?”…스타벅스는 ‘푸른 용’에 꽃혔다',
#   '활발한 제3지대 움직임…이준석 "세력 교체" · 이낙연 "큰 싸움"',
#   '이코노미스트 “새해 지구촌 10대 화두…선거·경제적 불확실성·AI 등”',
#   '7.6 강진에 5m 쓰나미…북·러도 경보 발령',
#   "남북 '적대관계' 규정하더니…김정은, 군 지휘관 소집해 내린 지시",
#   'UKRAINE RUSSIA CONFLICT',
#   'UKRAINE RUSSIA CONFLICT',
#   'UKRAINE RUSSIA CONFLICT',
#   'K반도체가 ‘반도체’ 했다…3개월 연속 한국 수출증가 이끌어',
#   '트럼프 재집권 할까, 신냉전 가열되나…새해 지구촌 10대 화두',
#   '"좀 더 살래" 집 빼기로 했다가 말 바꾼 세입자…대법 판단은?',
#   '상거래채권 갚겠다던 태영건설, 외담대 뺐다..협력사 자금난 우려',
#   '차기 대통령 선호도…이재명 27% 한동훈 22%[코리아리서치]',
#   '\'음주 산행\' 구조했더니…"한잔할 수도 있지, 참견 말라"',
#   '민주당 "총선에서 표로 정권 심판하겠다"…정통성 강조',
#   '[사진뉴스] 백마강참숯민물장어, 유성구행복누리재단에 후원금 기탁',
#   "북한, 함북 해안에 '지진해일 특급 경보' 발령",
#   "한동훈, 오는 3일 대한노인회 방문…'노인 폄하' 논란 직접 사과",
#   '이준석, 이낙연과 연대설에 “상호 보완적 결합할 수 있는 대상”',
#   '우리 땅인데…일본, 독도에 ‘쓰나미 주의보’ 발령',
#   "'근엄이 왕자' 할머니 덴마크 여왕..즉위 52주년 앞두고 '퇴위' 선언",
#   '`투머치토커` 옆자리 동료..."그렇게 자란 거였다"',
#   '"北으로 더 큰 지진해일 갔을 것" ...日 쓰나미 예상 높이 3∼5m [Y녹취록]',
#   "한동훈, 3일 대한노인회 방문…민경우 '노인비하' 발언 재차 사과",
#   '미 연준은 ‘균열’을 본 것인가',
#   '[신년사] 경기도의회 국힘 김정호 대표의원 "\'강구연월(康衢煙月)\' 위해 불철주야 달리겠다"',
#   '국민의힘 "정교한 정책 준비할 것…이기는 공천이어야"',
#   '미군-후티 반군 첫 교전‥막힌 홍해 열릴까?',
#   '외교부 “현재까지 일본 지진 교민 피해 접수 없어”',
#   '원안위 "日 지진 관련 동해안 원전 특이사항 없어"',
#   '유명 개그맨·배우 내세운 車리스업체…사기 혐의 피소, 대표자 잠적',
#   '"올해 \'백악관의 트럼프\' 다시 보나‥한미 관계는?"',
#   '[세상읽기] 빈곤과 고립이 없는 세상을 바라며',
#   'AUSTRALIA TENNIS',
#   '[정동칼럼] 어제와 오늘과 내일의 이야기',
#   '[일본 강진] 동해 묵호 최고 67㎝ 지진해일.."24시간 이상 지속될 수 있다"',
#   "[단독] '엽기 성폭행' 중학생, 성매매 업소 여성 유인도 시도했다",
#   '올 수출 ‘나홀로 강세’ 예상…내수 부진탓 경기회복은 난망',
#   '“수능 수학 최고점자 84%가 남학생”...최상위권 성별 격차',
#   '동해 지진해일 최대 67㎝...기상청 "24시간 이상 지속될 수도"',
#   'PK 국정안정 47.7% 국정견제 43.4%…국민의힘 50.3% 더불어민주당26.7%',
#   '한쪽은 폭죽, 한쪽은 포성‥새해 첫날 달랐던 지구촌',
#   '(3rd LD) Small tsunamis hit S. Korea after earthquake in Japan',
#   '음성군, 불법소각 금지 당부',
#   '[이선의 인물과 식물] 김대중과 인동덩굴',
#   '단양군 2024년 추진할 마스터플랜 7개 사업 발표',
#   '‘정부 견제론’ 우세하지만 “야당에 투표” 쏠림은 없었다',
#   '[기자칼럼] 16년 전으로 퇴행한 하천정책',
#   '원안위 "동해안 원전 10m 해일 견뎌…일본 지진 영향 없어"',
#   '한동훈, 대한노인회 방문한다…‘노인비하 발언’ 사과',
#   '‘행복한 철학자’가 되고픈 당신을 위한 몇 가지 조언',
#   '"\'도이치\' 담당 검사 지원도 없이 인사발령"…법무부 "허위 사실"',
#   '[여론조사②] 이준석·이낙연 신당 출범 시 영향력은?',
#   '“새해에는 이자부담 1%라도 더 줄이자” 상품별 대출금리 제일 낮은 은행은 어디?[머니뭐니]',
#   '괴산군, 연말연시 청소년유해환경 민·관 합동점검 진행',
#   '보은군 2023년 주민과 함께하는 신 활력성과공유회',
#   '동해안 지진 해일 시작…기상청 "24시간 이상 지속"',
#   '영동곶감축제 달고 쫀 득한 맛의 향연',
#   "'3개월 장관' 비판 속…방문규, 출판기념회 홍보 메시지 '도마'",
#   '[양권모 칼럼] 전쟁 같은 양당 정치, 신당이 허물길',
#   '\'신도 성폭행\' 이재록 목사 사망‥"범행은 끝내 인정 안 해"',
#   "청주시, '냉동난자 사용 보조생식술 지원 사업' 새롭게 추진...난임 가정 경제적 부담 완화",
#   "태안군, '지역 청소년들의 신나는 축제' 태안 유스 콘서트",
#   '청룡해 첫둥이는 난임 12년 부부의 ‘아홍이’',
#   "'차기 대통령감' 한동훈 24%·이재명 22%...다자대결 첫 우위",
#   'HUNGARY NEW YEAR',
#   '광주 서구을 “양부남 37.4%”…‘독주 양상’',
#   'INDIA LABOUR BRICK',
#   '서천판교 근대역사 종합정비계획, 문화재청 300억원 밑그림 확정',
#   '송연광 농협 서산시지부장 취임',
#   '보령발전본부 주변지역 학생들에게 장학금 지급',
#   '"크고 단단한 하나" vs "큰 싸움 벌여야"…사실상 \'결별 수순\'',
#   "한동훈 3일 대한노인회 방문…민경우 전 비대위원 '노인 비하' 사과",
#   '최우영 구미(을) 예비후보, 불체포특권 포기 등 3대 특권 포기 선언!',
#   "'지방소멸 위기' 서천과 괴산은 정말 사라질까",
#   '日 강진 여파..동해안서 지진해일 시작 "원전 특이사항 없어"',
#   '"드론쇼 보려고 13시간 기다렸는데‥"‥새해 광안리 드론쇼 취소',
#   '한동훈 "동료 시민 위해"…이준석 "멋들어진 용어 쓴다고 바뀌는 것 아냐"',
#   "총선 100일 앞둔 여야, '수도권 지지율'·'사법리스크' 변수[정다운의 뉴스톡]",
#   '한동훈, 3일 대한노인회 찾아가 민경우 ‘노인 비하’ 발언 재차 사과',
#   '[MBC여론조사③] 대선주자 선호도 이재명 27%·한동훈 22%‥신당 중 1위는 이준석 신당',
#   '폭격도 허물지 못한 동심…일상 꿈꾸는 가자 어린이들',
#   '[생각그림] 나를 보자',
#   '[기고] ‘기회의 땅’ 라오스에서 무엇을 찾을 것인가',
#   '[박래군의 인권과 삶] 2024년에는 ‘해방’의 단초를 만들 수 있을까',
#   '[직설] 그럴수록 앞을 보세요',
#   '유명 연예인 앞세운 차량 리스업체, 사기 혐의 피소',
#   '일본 강진 여파…동해안에 지진해일 관측',
#   "저출생의 그늘‥'버스기사 태부족' 흔들리는 일본 대중교통",
#   "'노벨평화상' 방글라데시 유누스, 노동법 위반으로 6개월형 선고",
#   "'돌연 취소' 부산 새해맞이 광안리 드론쇼 1일 오후에야 진행",
#   '[뉴스하이킥] 의사이자 경제학자 "나를 만든 것은 8할이 \'이것\'"',
#   '日 강진 영향 묵호 최고 67㎝ 지진해일…"더 높아질 수 있다"(종합3보)',
#   '나경원 “한동훈, 尹과의 신뢰를 당정관계 자산으로 써야”',
#   '동해 묵호항 지진해일 최고 67cm…일본 강진에 동해안 지진해일 밀려와',
#   '대구 오피스텔 기준가 7.9%↓…2006년 이후 가장 큰 폭 하락',
#   "대한노인회 찾는 한동훈…민경우 '노인비하' 발언 사과",
#   '[여론조사①] 2024 총선 D-100…민주당·국민의힘 지지도 경합',
#   '"그저 일하는 게 바람"‥일자리 찾아 헤매는 노인들',
#   '日 강진에 쩍쩍 갈라진 도로…도쿄 디즈니랜드도 날벼락[영상]',
#   '“2명에 30만원이요?”…호텔 딸기뷔페 가격 50% 상승에도 “자리 없어요”',
#   'Don’t ignore cruel judgment in election',
#   "충남교육청, '빈대 정밀 진단 조사' 완료",
#   "대전대, 혜화아너스아카데미 'I덴티티팀' '충북관광 활성화 콘텐츠 공모전 수상",
#   "충남대병원 교육 관계자 3명, '국민교육발전유공 부총리 겸 교육부장관상' 수상",
#   '이택구 대전 서구을 예비후보 "12년 고인물 퍼내는 갑진년 되길"',
#   'Nuclear weapons cannot solve anything',
#   '가야산국립공원사무소 박현상 소장 부임',
#   '대전시특별사법경찰관, 의료폐기물 처리기준 위반 동물병원 2개소 적발',
#   '‘信바람’ 타고… 더 나은 내일 꿈꾼다 [2024 신년특집]',
#   'Why leave the first lady risk unattended?',
#   '대전대청중학교, 바자회 수익금 지역사회에 전액 기부',
#   '㈜아트텔링, 대덕특구에 메타버스 관련 연구소 기업 설립',
#   '신성수 용인시 기획조정실장 "시정방침 구현할 일하는 조직으로"',
#   '[사설] 윤 정부 3년차, 국정에 새바람을 불어넣을 때',
#   '놀이터가 어르신 시설로‥저출생의 역습',
#   '외교부 "일본강진 한국인 피해여부 확인중…현재까진 없어"',
#   '北 노동신문 1월 1일 1면에 등장한 김주애…세습 본격화? [뉴스와이드]',
#   '[사설] 총선의 해, 지역 현안사업 공약으로 못 박아야',
#   "'이준석 신당' 이달 중순 창당…국힘 문병호 전 의원 합류(종합)",
#   '동해 묵호 최고 67㎝…일본 강진에 동해안 지진해일 밀려와(종합2보)',
#   '북한, 日 강진으로 함북 해안에 "지진해일 특급경보"',
#   '풍요·호국의 상징…용띠 시민들의 2024 새해 소망은?',
#   '\'쌀의 몰락\'... "쌀 정책 대전환 필요"',
#   '하은호 군포시장 "강한 의지로 정성다하면 무엇이든 해낼수 있다"',
#   '전북특별자치도 출범 3주 앞으로..무엇이 바뀌나?',
#   '[정수종의 기후변화 이야기] 도시숲, 석유 왕국이 꿈꾸는 미래',
#   '"푸른 청룡의 기운담아"..2024년 새해 해맞이',
#   'How will the North provoke the South this time?',
#   '대책은 나오는데‥"2백만원 씁니다‥퇴사 각오하고 휴직"',
#   "[MBC여론조사②] '야당 후보 당선돼야' 52%VS'여당 후보 당선돼야' 41%",
#   '광주 서구갑 “송갑석 22.1%·강위원 19.8%”…‘초접전’',
#   '日서 규모 7.6 지진 발생…쓰나미 경보 발령',
#   '김건희 특검 vs 이재명 사법리스크…어느 쪽이 치명타? [뉴스와이드]',
#   '[신년사] 박승원 광명시장 “광명의 더 나은 미래 위해 더 큰 변화 만들 것”',
#   'Let me save the people!',
#   "한동훈, '민경우 노인폄하 발언 논란' 대한노인회 찾아 사과키로",
#   "'갑진년' 푸른 용의 해 밝았다…2024년 첫 순간들 보니",
#   '서국동 NH농협손보 대표이사 취임',
#   '기차 멈추고, 3만9천가구 정전…일 “즉시 대피” 긴급방송',
#   '김정은, 딸 주애와 팔짱끼고 뽀뽀…간부들은 ‘물개박수’',
#   "북한, 日 강진에 함경북도 해안 '지진해일 특급 경보'",
#   '한동훈, ‘노인 비하’ 사과차 오는 3일 대한노인회 방문',
#   '2일 전국 곳곳 눈·비…큰 추위는 없어 [날씨]',
#   'Early staging of tripartite summit holds the key',
#   '급격한 인구 감소‥"경제는 마이너스 성장"',
#   '동해해경, 해안가 CCTV 점검',
#   '이준석 신당·이낙연 신당…무당층 표심 어디로 갈까? [뉴스와이드]',
#   '"훌륭한 연구성과"라더니 돌아온 건…\'후폭풍\' 벌써 시작됐다',
#   '수영구 연일 망신살…드론 쇼 또 연기했다 20분 뒤 진행',
#   '유명 개그맨 내세운 리스업체…사기 혐의 피소',
#   '일본 지진 해일 피해 발생..."동해안도 위험한 상황"',
#   '[내일날씨] 큰 추위 없어…대체로 흐리고 구름 많아',
#   '기상청 "동해안도 지진해일 관측"…\'해수면 상승\' 안전 주의',
#   '[자막뉴스] "강진 또 올 수 있다" 日 기상청 경고...건물 잔해에 깔린 사람도',
#   '정당 지지율과 다른 총선 투표 의향 여론…원인은? [뉴스와이드]',
#   '12만 5천년 만에 가장 뜨거웠던 2023년..올해는?',
#   '日 7.6 강진 여파 한국에…동해안서 지진해일 시작됐다',
#   '해안가 순찰 나선 동해해경',
#   "'신도 상습 성폭행' 이재록 목사, 형집행정지 중 사망",
#   '군, 새해 첫날 포탄 사격훈련‥북한은 "언제든 무력충돌 가능"',
#   '도쿄서도 진동 느껴져…지진 지역 원자력 발전소 괜찮나?',
#   '원성 샀던 그 현수막들 덜 보게 될까…2024 새해 달라지는 것',
#   '포항 남·울릉 이상휘 예비후보, 깨끗하고 반듯한 힘 있는 정치 약속',
#   '포항 남·울릉 최용규 예비후보 “불체포특권 포함해 모든 기득권 내려놓겠다”',
#   '“해변 주민 즉시 대피”…지진해일 영동지역에 비상 1단계 발령',
#   "몸 싣고 꿈 싣고…새해 첫날, 146번 '새벽 만원버스' 풍경",
#   '이철우 경북도지사 "지역 발전 민간 중심 전환…청룡처럼 비상하는 한 해 만들 것"',
#   '“먹으러 간 네가 바보”…떡볶이도 10분만에 1천원 ‘쑥’, 값질도 실시간?',
#   '해안가 순찰 나선 동해해경',
#   '해안가 순찰 나선 동해해경',
#   '해안가 순찰 나선 동해해경',
#   '정박 어선 살피는 동해해경',
#   '日서 한신대지진 보다 큰 규모 7.6 강진…대형 쓰나미 경보 발령(종합2보)',
#   '정박 어선 살피는 동해해경',
#   '윤 대통령 신년사 "이념 패거리 카르텔 타파"',
#   '"문제는 안보야"… 독일, 징병제 재도입 검토 나서나',
#   '[속보] 지진해일 최대 높이 묵호 67㎝…"더 높아질 수 있어"',
#   '홍준표 시장 "대구 미래 50년 밑그림 완성…TK신공항 SPC 구성 속도 낼 것"',
#   '[날씨] 갑진년, 새해 첫 해돋이 무난…내일 큰 추위 없어요',
#   '[포토] 울주군, 2024 간절곶 해맞이행사 개최',
#   '대구 출발 한동훈 vs 부산 출발 이재명 분석은? [뉴스와이드]',
#   '묵호 67㎝·속초 41㎝…日 지진해일 동해안 밀려와',
#   "한동훈, 3일 대한노인회 방문… 민경우 '노인비하' 발언 사과",
#   '김정은 “통일 불가” vs 尹 “북핵 원천봉쇄”',
#   '이재명, 故 김대중·노무현 찾아 \'통합\' 과시‥이낙연 "새로운 선택"',
#   "특허 완료 앞둔 빅파마, '메가 딜'(Deal) 늘렸다",
#   '광주 동남갑 선거구 “정진욱 25.2%·노형욱 21.2%·윤영덕 16.7%·오경훈 15.2%”',
#   '[인사] 안양시',
#   '[사설]‘이념 패거리 카르텔 타파’가 대통령 신년사에 담길 말인가',
#   "대구경북 경제 대전환 싹 키워 '제2의 낙동강 기적' 일구자",
#   '수입차, 덜컥 샀다가 후회?…4천만원 이상車 보유 어르신, 기초연금 못받는다',
#   '새해 첫날 일본 이시카와현에 규모 7.6 강진…쓰나미 경보 발령',
#   '강원 동해안 해안가 통제',
#   '동해안서 지진해일 시작…기상청 "0.5m 미만 예상"',
#   '제약·바이오 리더들 “불확실성 크지만 연구개발과 혁신 노력 지속해야”',
#   '수도권 향한 사람들… 청년층 잡기 고군분투 역부족',
#   '외교부 “日지진 관련 우리 국민 피해 접수되지 않아”',
#   '“회개와 반성, 자비로 2024년 새해 맞이해야”',
#   '日 지진해일 포항 해안 도달…순찰 강화 "피해는 아직"',
#   "'동료 시민' 앞세운 한동훈‥'김건희 특검법' 놓고 이준석과 대립",
#   '동해안서 지진해일 시작…“24시간 이상 지속될 수도”',
#   '전현무도 김숙도 “죽기전에 꼭 갈래”…스타들이 꼽은 최애 여행지는 [여프라이즈]',
#   '강원 동해안 해안가 파도',
#   '속초시 해안가 지진해일 대비 접근 통제',
#   '‘현존 최장 52년 재위’ 덴마크 여왕 퇴위',
#   '자회사서 3.2조 수혈 한전, 채권 10조 추가 발행 ‘숨통’',
#   "[MBC여론조사①] 국정운영 '잘못한다' 59%‥특검 거부권 '동의 안 해' 64%",
#   '‘돈잔치’ 눈총에… 희망퇴직 조건 나빠진 은행권',
#   '불확실성 커진 경제 환경… “도전과 혁신으로 뛰어넘자”',
#   'LG전자 ‘CES’서 혁신 제품 대거 선보인다',
#   "아홍이의 우렁찬 울음…청룡의 해, 힘차게 내디딘 '첫 순간들'",
#   '日 강진에 동해안 지진해일 피해 \'우려\'…"아직 피해 없지만 예의주시"',
#   '속초시 해안가 지진해일 대비 접근 통제',
#   '부산대 지하철역서 흉기 들고 배회한 20대 남성',
#   'epaselect NETHERLANDS NEW YEAR',
#   '새해 밝히는 롯데월드타워 불꽃쇼',
#   '영세 소상공인 126만명, 1인당 20만원 전기요금 감면받는다',
#   '동해안에도 지진해일…"24시간 지속될 수도" 주의 당부',
#   '“드디어 떴다”... 두 번 만에 성공한 부산 광안리해수욕장 드론 공연',
#   ...],
#  'dates': ['20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   '20240101',
#   ...]}

# %%
load_raw_data('20240101', '20240103')
# Out:
#                                              0     dates
# 0      [사설]尹 3년차도 “카르텔 타파”… 이젠 개혁과제 실행에 더 진력해야  20240101
# 1        일본서 한신 대지진보다 큰 규모 7.6 강진…"피해 현황 집계 중"  20240101
# 2                  동해안에도 지진해일 여파...인명·물적 피해 없어  20240101
# 3                     [라인W 날씨] 내일 오전까지 중부에 눈·비  20240101
# 4      성낙인 창녕군수 “2024년 청룡처럼 비상하는 창녕 되도록 노력할 것”  20240101
# ...                                        ...       ...
# 56145                     국무회의, 쌍특검법 거부권 의결 연기  20240103
# 56146   김여정, 尹 신년사 저격…"안보 불안 일상사 된 건 윤 대통령 공로"  20240103
# 56147           사우디, ‘러·중 주도’ 브릭스 회원국 가입 공식 발표  20240103
# 56148          울산농협, 갑진년 시무식·3행(行) 3무(無) 실천 결의  20240103
# 56149      “미국 기업·미국인에 뇌물 받은 외국정부 관리도 미국에서 처벌”  20240103
#
# [56150 rows x 2 columns]

# %%
import util

# %%
util.run()
# Out:
# 분석 시작 지점을 예시와 같이 입력하시오 (ex. 2024년 1월 1일 -> 20240101) 20240101
# 분석 종료 지점을 예시와 같이 입력하시오 (ex. 2024년 1월 1일 -> 20240101) 20240201
# 	분석 시작일 : 2024년 01월 01일
# 	분석 종료일 : 2024년 02월 01일
# 맞으면 y, 틀리면 n을 입력하시오([y]/n) y
# load data
# True
